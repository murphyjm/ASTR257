# %%
# Imports
import os
import numpy as np
from astropy.table import Table

# Pandas
import pandas as pd

# Matplotlib
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams["font.family"] = "serif"
rcParams["font.serif"] = "Times New Roman"
# %matplotlib inline
#%matplotlib notebook
rcParams['text.usetex'] = True
rcParams['text.latex.preamble'] = [r'\usepackage{amsmath} \usepackage{bm} \usepackage{physics}']
# %config InlineBackend.figure_format = 'retina' # For high quality figures
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Load the tables from the PSF Photometry

# %%
data_folder = "data-2019-09-23-nickel-joey-anne"
OVERWRITE   = True
n_iters     = 1

# %%
ngc6819_v_tab = Table.read(os.path.join(data_folder, 'photometry/ngc6819_v_iter_{}.dat'.format(n_iters)), 
                           format='ascii')
ngc6819_b_tab = Table.read(os.path.join(data_folder, 'photometry/ngc6819_b_iter_{}.dat'.format(n_iters)), 
                           format='ascii')
ngc6819_v_pd  = ngc6819_v_tab.to_pandas()
ngc6819_b_pd  = ngc6819_b_tab.to_pandas()

# %% [markdown]
# ## Make sure that the tables are the same length

# %%
try:
    assert len(ngc6819_v_pd) == len(ngc6819_b_pd), " "
    print("The tables are the same length.")
except:
    print("len(ngc6819_v_pd) = {}, len(ngc6819_b_pd) = {}.".format(len(ngc6819_v_pd), len(ngc6819_b_pd)))
    # I checked by hand which row from ngc6819_v_pd was extra compared to ngc6819_b_pd 
    # and remove it by it's row index: 
    # **This only applies to ngc6819_v_iter_1.dat & ngc6819_b_iter_1.dat, ngc6819_v_iter_2.dat & ngc6819_b_iter_2.dat**
    print("dropping row...")
    ngc6819_v_pd.drop(axis=0, index=1, inplace=True)
    print("len(ngc6819_v_pd) = {}, len(ngc6819_b_pd) = {}.".format(len(ngc6819_v_pd), len(ngc6819_b_pd)))
# Out:
# len(ngc6819_v_pd) = 492, len(ngc6819_b_pd) = 491.
# dropping row...
# len(ngc6819_v_pd) = 491, len(ngc6819_b_pd) = 491.

# %% [markdown]
# ## Source match by merging the two dataframes (within tolerance)

# %%
# Add an r_0 column for merging on
ngc6819_v_pd['r_0'] = np.sqrt(np.square(ngc6819_v_pd['y_0']) + np.square(ngc6819_v_pd['x_0']))
ngc6819_b_pd['r_0'] = np.sqrt(np.square(ngc6819_b_pd['y_0']) + np.square(ngc6819_b_pd['x_0']))

# %%
merged_asof = pd.merge_asof(ngc6819_v_pd.sort_values('r_0'), ngc6819_b_pd.sort_values('r_0'), 
              on='r_0', by=['id'], suffixes=['_v', '_b'], tolerance=1., direction='nearest')
display(HTML(merged_asof.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>x_0_v</th>
#       <th>x_fit_v</th>
#       <th>y_0_v</th>
#       <th>y_fit_v</th>
#       <th>flux_0_v</th>
#       <th>flux_fit_v</th>
#       <th>id</th>
#       <th>group_id_v</th>
#       <th>flux_unc_v</th>
#       <th>x_0_unc_v</th>
#       <th>y_0_unc_v</th>
#       <th>iter_detected</th>
#       <th>r_0</th>
#       <th>x_0_b</th>
#       <th>y_0_b</th>
#       <th>flux_0_b</th>
#       <th>group_id_b</th>
#       <th>x_fit_b</th>
#       <th>y_fit_b</th>
#       <th>flux_fit_b</th>
#       <th>flux_unc_b</th>
#       <th>x_0_unc_b</th>
#       <th>y_0_unc_b</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>63.870266</td>
#       <td>63.837860</td>
#       <td>47.947862</td>
#       <td>47.909188</td>
#       <td>36095.096089</td>
#       <td>32972.772169</td>
#       <td>30</td>
#       <td>27</td>
# ...

# %%
fig, ax = plt.subplots(ncols=2, figsize=(12,5))
[ax_.set_aspect('equal') for ax_ in ax]
ax[0].plot(merged_asof['x_0_v'], merged_asof['x_0_b'], '.', alpha=0.3, label='Sorted')
ax[0].plot(ngc6819_v_pd['x_0'], ngc6819_b_pd['x_0'], '.', alpha=0.3, label='Unsorted')
ax[0].set_xlabel('x0 V')
ax[0].set_ylabel('x0 B')
ax[0].legend()

ax[1].plot(merged_asof['y_0_v'], merged_asof['y_0_b'], '.', alpha=0.3, label='Sorted')
ax[1].plot(ngc6819_v_pd['y_0'], ngc6819_b_pd['y_0'], '.', alpha=0.3, label='Unsorted')
ax[0].set_xlabel('y0 V')
ax[0].set_ylabel('y0 B')
ax[1].legend()

plt.show()

# %% [markdown]
# # *Sources look matched!*

# %% [markdown]
# ### Clean things up by getting rid of some extraneous columns

# %%
merged_asof = merged_asof.drop(labels=['id', 'group_id_v', 'iter_detected', 'r_0', 'group_id_b'], axis=1)
display(HTML(merged_asof.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>x_0_v</th>
#       <th>x_fit_v</th>
#       <th>y_0_v</th>
#       <th>y_fit_v</th>
#       <th>flux_0_v</th>
#       <th>flux_fit_v</th>
#       <th>flux_unc_v</th>
#       <th>x_0_unc_v</th>
#       <th>y_0_unc_v</th>
#       <th>x_0_b</th>
#       <th>y_0_b</th>
#       <th>flux_0_b</th>
#       <th>x_fit_b</th>
#       <th>y_fit_b</th>
#       <th>flux_fit_b</th>
#       <th>flux_unc_b</th>
#       <th>x_0_unc_b</th>
#       <th>y_0_unc_b</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>63.870266</td>
#       <td>63.837860</td>
#       <td>47.947862</td>
#       <td>47.909188</td>
#       <td>36095.096089</td>
#       <td>32972.772169</td>
#       <td>989.154387</td>
#       <td>0.085803</td>
#       <td>0.085799</td>
#       <td>64.297549</td>
#       <td>48.633034</td>
#       <td>9332.428767</td>
#       <td>63.521063</td>
# ...

# %% [markdown]
# ### Drop any rows that weren't successfully matched in the merge

# %%
merged_asof = merged_asof.dropna()
display(HTML(merged_asof.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>x_0_v</th>
#       <th>x_fit_v</th>
#       <th>y_0_v</th>
#       <th>y_fit_v</th>
#       <th>flux_0_v</th>
#       <th>flux_fit_v</th>
#       <th>flux_unc_v</th>
#       <th>x_0_unc_v</th>
#       <th>y_0_unc_v</th>
#       <th>x_0_b</th>
#       <th>y_0_b</th>
#       <th>flux_0_b</th>
#       <th>x_fit_b</th>
#       <th>y_fit_b</th>
#       <th>flux_fit_b</th>
#       <th>flux_unc_b</th>
#       <th>x_0_unc_b</th>
#       <th>y_0_unc_b</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>63.870266</td>
#       <td>63.837860</td>
#       <td>47.947862</td>
#       <td>47.909188</td>
#       <td>36095.096089</td>
#       <td>32972.772169</td>
#       <td>989.154387</td>
#       <td>0.085803</td>
#       <td>0.085799</td>
#       <td>64.297549</td>
#       <td>48.633034</td>
#       <td>9332.428767</td>
#       <td>63.521063</td>
# ...

# %% [markdown]
# # Save the merged and matched table

# %%
merged_asof_tab = Table.from_pandas(merged_asof)

# %%
try:
    merged_asof_tab.write(os.path.join(data_folder, 'photometry/merged_asof_iter_{}.dat'.format(n_iters)), 
                          format='ascii', 
                          overwrite=OVERWRITE)
except:
    print("Warning: Did not overwrite file.")
